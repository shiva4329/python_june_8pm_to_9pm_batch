# %%
from Modules.sub_module1 import fn1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Modules.sub_module1 import fn1
#
# ModuleNotFoundError: No module named 'Modules'

# %%
import os

print(os.getcwd())
# Out:
# /home/siva/Documents/python_june_8pm_to_9pm_batch/python_june_8pm_to_9pm_batch/Modules/sub_module2

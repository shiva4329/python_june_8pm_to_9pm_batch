# %%
# !apt install pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName(
    'Read CSV File into DataFrame').getOrCreate()

authors = spark.read.csv('/home/siva/Downloads/authors.csv', sep=',',
                         inferSchema=True, header=True)

df = authors.toPandas()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder.appName(
#       4     'Read CSV File into DataFrame').getOrCreate()
#       6 authors = spark.read.csv('/home/siva/Downloads/authors.csv', sep=',',
#       7                          inferSchema=True, header=True)
#
# ModuleNotFoundError: No module named 'pyspark'
